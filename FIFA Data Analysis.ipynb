# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import warnings

# %%
df=pd.read_csv('players_20.csv')
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
df.shape
# Out:
# (18278, 104)

# %%
for col in df.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18278 entries, 0 to 18277
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(16), int64(45), object(43)
# memory usage: 14.5+ MB

# %%
pd.isnull(df).sum().head(50)
# Out:
# sofifa_id                         0
# player_url                        0
# short_name                        0
# long_name                         0
# age                               0
# dob                               0
# height_cm                         0
# weight_kg                         0
# nationality                       0
# club                              0
# overall                           0
# potential                         0
# value_eur                         0
# wage_eur                          0
# player_positions                  0
# preferred_foot                    0
# international_reputation          0
# weak_foot                         0
# skill_moves                       0
# work_rate                         0
# body_type                         0
# real_face                         0
# release_clause_eur             1298
# player_tags                   16779
# team_position                   240
# team_jersey_number              240
# ...

# %%
df.drop(['ls',
'st',
'rs',
'lw',
'lf',
'cf',
'rf',
'rw',
'lam',
'cam',
'ram',
'lm',
'lcm',
'cm',
'rcm',
'rm',
'lwb',
'ldm',
'cdm',
'rdm',
'rwb',
'lb',
'lcb',
'cb',
'rcb',
'rb'],axis=1,inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# sofifa_id                  0
# player_url                 0
# short_name                 0
# long_name                  0
# age                        0
#                           ..
# goalkeeping_diving         0
# goalkeeping_handling       0
# goalkeeping_kicking        0
# goalkeeping_positioning    0
# goalkeeping_reflexes       0
# Length: 78, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18278 entries, 0 to 18277
# Data columns (total 78 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   sofifa_id                   18278 non-null  int64
#  1   player_url                  18278 non-null  object
#  2   short_name                  18278 non-null  object
#  3   long_name                   18278 non-null  object
#  4   age                         18278 non-null  int64
#  5   dob                         18278 non-null  object
#  6   height_cm                   18278 non-null  int64
#  7   weight_kg                   18278 non-null  int64
#  8   nationality                 18278 non-null  object
#  9   club                        18278 non-null  object
#  10  overall                     18278 non-null  int64
#  11  potential                   18278 non-null  int64
#  12  value_eur                   18278 non-null  int64
# ...

# %%
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...  \
# 0        170         72   Argentina         FC Barcelona  ...
# ...

# %%
df['nationality'].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
df['nationality'].value_counts().head(15) #df['nationality'].value_counts()[0:15]
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
# Brazil                  824
# Italy                   732
# Colombia                591
# Japan                   453
# Netherlands             416
# China PR                373
# Chile                   370
# Sweden                  358
# Norway                  350
# Republic of Ireland     348
# Name: nationality, dtype: int64

# %%
df['nationality'].value_counts().head(10).keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina', 'Brazil', 'Italy',
#        'Colombia', 'Japan', 'Netherlands'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
plt.bar(df['nationality'].value_counts().head(10).keys(),df['nationality'].value_counts().head(10))
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18278 entries, 0 to 18277
# Data columns (total 78 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   sofifa_id                   18278 non-null  int64
#  1   player_url                  18278 non-null  object
#  2   short_name                  18278 non-null  object
#  3   long_name                   18278 non-null  object
#  4   age                         18278 non-null  int64
#  5   dob                         18278 non-null  object
#  6   height_cm                   18278 non-null  int64
#  7   weight_kg                   18278 non-null  int64
#  8   nationality                 18278 non-null  object
#  9   club                        18278 non-null  object
#  10  overall                     18278 non-null  int64
#  11  potential                   18278 non-null  int64
#  12  value_eur                   18278 non-null  int64
# ...

# %%
player_salary=df[['long_name','wage_eur']]

# %%
player_salary.head().sort_values(by='wage_eur',ascending=False)
# Out:
#                              long_name  wage_eur
# 0       Lionel Andrés Messi Cuccittini    565000
# 4                          Eden Hazard    470000
# 1  Cristiano Ronaldo dos Santos Aveiro    405000
# 2        Neymar da Silva Santos Junior    290000
# 3                            Jan Oblak    125000

# %%
plt.figure(figsize=(20,8))
plt.bar(player_salary['long_name'].head(5),player_salary['wage_eur'].head(5))
plt.show()

# %%
germany=df[df['nationality']=='Germany']
germany
# Out:
#        sofifa_id                                         player_url  \
# 6         192448  https://sofifa.com/player/192448/marc-andre-te...
# 31        167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36        182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37        188350  https://sofifa.com/player/188350/marco-reus/20...
# 49        178603  https://sofifa.com/player/178603/mats-hummels/...
# ...          ...                                                ...
# 18123     252076  https://sofifa.com/player/252076/lukas-schelle...
# 18156     251856  https://sofifa.com/player/251856/dominik-meise...
# 18186     243537  https://sofifa.com/player/243537/maximilian-br...
# 18191     244043  https://sofifa.com/player/244043/nico-stephan/...
# 18197     244172  https://sofifa.com/player/244172/matthis-harsm...
#
#             short_name              long_name  age         dob  height_cm  \
# 6        M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# ...

# %%
germany.sort_values(by='height_cm',ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 8016      236831  https://sofifa.com/player/236831/aaron-seydel/...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 11859     167437  https://sofifa.com/player/167437/dominik-stroh...
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
#
#            short_name            long_name  age         dob  height_cm  \
# 8016        A. Seydel         Aaron Seydel   23  1996-02-07        199
# 1217         M. Esser        Michael Esser   31  1987-11-22        198
# 1389    L. Unnerstall      Lars Unnerstall   28  1990-07-20        198
# 11859  D. Stroh-Engel  Dominik Stroh-Engel   33  1985-11-27        197
# 13576    L. Watkowiak      Lukas Watkowiak   23  1996-03-06        197
#
#        weight_kg nationality                club  ...  mentality_penalties  \
# ...

# %%
germany.sort_values(by='weight_kg',ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 518       179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 77        212190  https://sofifa.com/player/212190/niklas-sule/2...
#
#           short_name        long_name  age         dob  height_cm  weight_kg  \
# 13576   L. Watkowiak  Lukas Watkowiak   23  1996-03-06        197        103
# 1389   L. Unnerstall  Lars Unnerstall   28  1990-07-20        198        103
# 518      R. Fährmann    Ralf Fährmann   30  1988-09-27        197         98
# 1217        M. Esser    Michael Esser   31  1987-11-22        198         97
# 77           N. Süle      Niklas Süle   23  1995-09-03        195         97
#
#       nationality                club  ...  mentality_penalties  \
# ...

# %%
germany[['long_name','wage_eur']].sort_values(by='wage_eur',ascending=False).head()
# Out:
#                  long_name  wage_eur
# 36              Toni Kroos    330000
# 6    Marc-André ter Stegen    250000
# 55              Leroy Sané    195000
# 146         İlkay Gündoğan    180000
# 70           Thomas Müller    170000

# %%
player_shoot=df[['long_name','shooting']]

# %%
player_shoot.sort_values(by='shooting',ascending=False).head()
# Out:
#                                long_name  shooting
# 1    Cristiano Ronaldo dos Santos Aveiro      93.0
# 0         Lionel Andrés Messi Cuccittini      92.0
# 12                            Harry Kane      91.0
# 17     Sergio Leonel Agüero del Castillo      90.0
# 205                   Fabio Quagliarella      89.0

# %%
eng=df[df['nationality']=='England']
eng=eng[['long_name','defending','nationality','club']]
defending=eng[['long_name','defending','nationality','club']]
defending.sort_values(by='defending',ascending=False)
# Out:
#                     long_name  defending nationality               club
# 172               John Stones       84.0     England    Manchester City
# 148               Kyle Walker       81.0     England    Manchester City
# 280             Harry Maguire       81.0     England  Manchester United
# 457             Michael Keane       80.0     England            Everton
# 616                 Eric Dier       80.0     England  Tottenham Hotspur
# ...                       ...        ...         ...                ...
# 18176         Ollie Battersby        NaN     England       Grimsby Town
# 18189           Arthur Janata        NaN     England      Leyton Orient
# 18209              Joe Wright        NaN     England           Millwall
# 18223          Liam Armstrong        NaN     England     Bristol Rovers
# 18251  George Sykes-Kenworthy        NaN     England      Bradford City
#
# [1667 rows x 4 columns]

# %%
defending.groupby(['nationality'],as_index=False)['defending'].sum().sort_values(by='defending',ascending=False).head()
# Out:
#   nationality  defending
# 0     England    74040.0

# %%
pd.isnull(eng).sum()
# Out:
# long_name        0
# defending      170
# nationality      0
# club             0
# dtype: int64

# %%
eng.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1667 entries, 12 to 18270
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   long_name    1667 non-null   object
#  1   defending    1497 non-null   float64
#  2   nationality  1667 non-null   object
#  3   club         1667 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 65.1+ KB

# %%
eng.shape
# Out:
# (1667, 4)

# %%
real_madrid=df[df['club']=='Real Madrid']
real_madrid.head()
# Out:
#     sofifa_id                                         player_url  \
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 28     192119  https://sofifa.com/player/192119/thibaut-court...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
#
#       short_name            long_name  age         dob  height_cm  weight_kg  \
# 4      E. Hazard          Eden Hazard   28  1991-01-07        175         74
# 8      L. Modrić          Luka Modrić   33  1985-09-09        172         66
# 18  Sergio Ramos  Sergio Ramos García   33  1986-03-30        184         82
# 28   T. Courtois     Thibaut Courtois   27  1992-05-11        199         96
# 36      T. Kroos           Toni Kroos   29  1990-01-04        183         76
#
#    nationality         club  ...  mentality_penalties  mentality_composure  \
# ...

# %%
real_madrid.sort_values(by='wage_eur',ascending=False).head()
# Out:
#     sofifa_id                                         player_url  \
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 46     165153  https://sofifa.com/player/165153/karim-benzema...
#
#       short_name            long_name  age         dob  height_cm  weight_kg  \
# 4      E. Hazard          Eden Hazard   28  1991-01-07        175         74
# 8      L. Modrić          Luka Modrić   33  1985-09-09        172         66
# 36      T. Kroos           Toni Kroos   29  1990-01-04        183         76
# 18  Sergio Ramos  Sergio Ramos García   33  1986-03-30        184         82
# 46    K. Benzema        Karim Benzema   31  1987-12-19        185         81
#
#    nationality         club  ...  mentality_penalties  mentality_composure  \
# ...

# %%
real_madrid1=real_madrid[['long_name','shooting']]
real_madrid.sort_values(by='shooting',ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 100     173731  https://sofifa.com/player/173731/gareth-bale/2...
# 106     198710  https://sofifa.com/player/198710/james-rodrigu...
# 4       183277  https://sofifa.com/player/183277/eden-hazard/2...
# 46      165153  https://sofifa.com/player/165153/karim-benzema...
# 161     232432  https://sofifa.com/player/232432/luka-jovic/20...
#
#        short_name                    long_name  age         dob  height_cm  \
# 100       G. Bale            Gareth Frank Bale   29  1989-07-16        185
# 106  J. Rodríguez  James David Rodríguez Rubio   27  1991-07-12        180
# 4       E. Hazard                  Eden Hazard   28  1991-01-07        175
# 46     K. Benzema                Karim Benzema   31  1987-12-19        185
# 161      L. Jović                   Luka Jović   21  1997-12-23        182
#
#      weight_kg nationality         club  ...  mentality_penalties  \
# ...

# %%
real_madrid.value_counts(['nationality'])
# Out:
# nationality
# Spain                 13
# Brazil                 6
# France                 3
# Belgium                2
# Colombia               1
# Costa Rica             1
# Croatia                1
# Dominican Republic     1
# Germany                1
# Japan                  1
# Serbia                 1
# Uruguay                1
# Wales                  1
# dtype: int64
